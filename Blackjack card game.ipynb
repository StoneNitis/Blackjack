# %%
import random
#Card detail
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

# %%
class Card():
#Each card 
    def __init__(self,suit,rank):
        self.suit = suit
        self.rank = rank
        
    def __str__(self):
        return self.rank + ' of ' + self.suit

# %%
class Deck(): 
#Create deck
    def __init__(self):
        self.deck = []  
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))  
    
    def __str__(self):
        deck_comp = ''  
        for card in self.deck:
            deck_comp += '\n '+card.__str__()
        return 'The deck has:' + deck_comp

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_card = self.deck.pop()
        return single_card

# %%
#test_deck = Deck()
#test_deck.shuffle() 
#print(test_deck)

# %%
class Hand:
#Card on hand
    def __init__(self):
        self.cards = []  
        self.value = 0   
        self.aces = 0    
    
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.rank]
        if card.rank == 'Ace':
            self.aces += 1
    
    def adjust_for_ace(self):
        while self.value > 21 and self.aces:
            self.value -= 10
            self.aces -= 1

# %%
#playtest_deck = Deck()
#playtest_deck.shuffle()
#playtest_player = Hand()
#playtest_player.add_card(playtest_deck.deal())
#playtest_player.add_card(playtest_deck.deal())

#for card in playtest_player.cards:
    #print(card)

# %%
class Chipscoin:
#Chipcoin for bet and bet result    
    def __init__(self):
        self.total = 100  
        self.bet = 0
        
    def win_bet(self):
        self.total += self.bet
    
    def lose_bet(self):
        self.total -= self.bet

# %%
def take_bet(chipscoin):
#Bet a chip    
    while True:
        try:
            chipscoin.bet = int(input('How many chips would you like to bet? '))
        except ValueError:
            print('Sorry, a amount of bet must be an integer!')
        else:
            if chipscoin.bet > chipscoin.total:
                print("Sorry, your bet can't be exceed",chipscoin.total)
            else:
                break

# %%
def hit(deck,hand):   
    hand.add_card(deck.deal())
    hand.adjust_for_ace()

# %%
def hit_or_stand(deck,hand):
    global playing  
    while True:
        x = input("Would you like to Hit or Stand? Enter 'H' or 'S' ")
        
        if x[0].lower() == 'h':
            hit(deck,hand)  

        elif x[0].lower() == 's':
            print("Player stands. Dealer is playing.")
            playing = False

        else:
            print("Sorry, please try again.")
            continue
        break

# %%
def show_some(player,dealer):
    print("\nDealer's Hand:")
    print(" <card hidden>")
    print('',dealer.cards[1])  
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    
def show_all(player,dealer):
    print("\nDealer's Hand:", *dealer.cards, sep='\n ')
    print("Dealer's Hand =",dealer.value)
    print("\nPlayer's Hand:", *player.cards, sep='\n ')
    print("Player's Hand =",player.value)

# %%
def player_busts(player,dealer,chipscoin):
    print("Player busts!")
    chips.lose_bet()

def player_wins(player,dealer,chipscoin):
    print("Player wins!")
    chips.win_bet()

def dealer_busts(player,dealer,chipscoin):
    print("Dealer busts!")
    chips.win_bet()
    
def dealer_wins(player,dealer,chipscoin):
    print("Dealer wins!")
    chips.lose_bet()
    
def push(player,dealer):
    print("Dealer and Player tie! It's a push.")

# %%
while True:
    #Gameplay
    print('Welcome to BlackJack!\nPlease take a seat\nThe rule is get as close to 21 as you can without going over!\n\
    Dealer hits until she reaches 17. Aces count as 1 or 11.')
    
    deck = Deck()
    deck.shuffle()
    
    player_hand = Hand()
    player_hand.add_card(deck.deal())
    player_hand.add_card(deck.deal())
    
    dealer_hand = Hand()
    dealer_hand.add_card(deck.deal())
    dealer_hand.add_card(deck.deal())
            

    player_chipscoin = Chipscoin()  #value is 100     
    take_bet(player_chipscoin)
    show_some(player_hand,dealer_hand)
    
    while playing:  
        
        hit_or_stand(deck,player_hand) 
        show_some(player_hand,dealer_hand)  
        
        if player_hand.value > 21:
            player_busts(player_hand,dealer_hand,player_chips)
            break        


    if player_hand.value <= 21:
        
        while dealer_hand.value < 17:
            hit(deck,dealer_hand)    
    
        show_all(player_hand,dealer_hand)
        
        if dealer_hand.value > 21:
            dealer_busts(player_hand,dealer_hand,player_chipscoin)

        elif dealer_hand.value > player_hand.value:
            dealer_wins(player_hand,dealer_hand,player_chipscoin)

        elif dealer_hand.value < player_hand.value:
            player_wins(player_hand,dealer_hand,player_chipscoin)

        else:
            push(player_hand,dealer_hand)        
    
    print("\nPlayer's winnings stand at",player_chipscoin.total)
    #play again    
    new_game = input("Would you like to play more game? Enter 'Y' or 'N' ")
    
    if new_game[0].lower()=='y':
        playing=True
        continue
    else:
        print("Thanks for playing blackjack!")
        break
# Out:
# Welcome to BlackJack!
# Please take a seat
# The rule is get as close to 21 as you can without going over!
#     Dealer hits until she reaches 17. Aces count as 1 or 11.
# How many chips would you like to bet? 50
#
# Dealer's Hand:
#  <card hidden>
#  Three of Hearts
#
# Player's Hand:
#  Three of Diamonds
#  Seven of Hearts
# Would you like to Hit or Stand? Enter 'H' or 'S' h
#
# Dealer's Hand:
#  <card hidden>
#  Three of Hearts
#
# Player's Hand:
#  Three of Diamonds
#  Seven of Hearts
#  Six of Diamonds
# Would you like to Hit or Stand? Enter 'H' or 'S' s
# Player stands. Dealer is playing.
#
# Dealer's Hand:
#  <card hidden>
#  Three of Hearts
#
# Player's Hand:
#  Three of Diamonds
#  Seven of Hearts
#  Six of Diamonds
#
# Dealer's Hand:
#  Eight of Clubs
#  Three of Hearts
#  Ten of Hearts
# Dealer's Hand = 21
#
# Player's Hand:
#  Three of Diamonds
#  Seven of Hearts
#  Six of Diamonds
# Player's Hand = 16
# Dealer wins!
#
# Player's winnings stand at 50
# ...
